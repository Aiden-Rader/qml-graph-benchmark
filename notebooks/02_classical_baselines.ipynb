# %% [markdown]
# # Classical Baseline
# ---

# %% [markdown]
# For this notebook, I will be using the classical Logistic Regression, Linear SVM, RBF SVM as our absolute classical baseline model. I will be using the [scikit-learn](https://scikit-learn.org/stable/) library for this.

# %%
import sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('All imports done and sklearn version is', sklearn.__version__)
# Out:
# All imports done and sklearn version is 1.9.0

# %% [markdown]
# Now that we have all the imports done, we can move on to the training process.
#
# ---

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# For our Logistic Regression, we want to use only the
